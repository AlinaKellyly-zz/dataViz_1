# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk

# %%
# Keep making Random Walks while program is running.
while True:
    rw = RandomWalk()
    rw.fill_walk()

    # Plot the points in the walk
    plt.style.use('classic')
    fig, ax = plt.subplots(figsize=(15, 9), dpi=128)
    
    point_numbers = range(rw.num_points)
    ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Blues, edgecolors='none', s=15)
    
    # Emphasize the first and last point
    ax.scatter(0,0, c='green', edgecolors='none', s=100)
    ax.scatter(rw.x_values[-1], rw.y_values[-1], c='red', edgecolors='none', s=100)
    
    # Remove the axes.
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    plt.show()
    
    keep_running = input('Make another one? y/n: ')
    if keep_running=='n':
        break
# Out:
# Make another one? y/n:  n

# %%
??rw.fill_walk
# Out:
# Signature: rw.fill_walk()
# Docstring:
# Calculate all the points in the walk
# :return:
# Source:
#     def get_step(self):
#         '''
#         Calculate each step and return it
#         :return: int
#         '''
#
#         # Decide which direction to go and how far to go in that direction.
#         direction = choice([-1, 1])
#         distance = choice([0, 1, 2, 3, 4])
#         step = distance * direction
#
#         return step
# File:      d:\projects\learn_python\dataviz_1\random_walk.py
# Type:      method
